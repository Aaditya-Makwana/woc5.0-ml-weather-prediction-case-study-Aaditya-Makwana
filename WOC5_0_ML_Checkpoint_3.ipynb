# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaditya-Makwana/woc5.0-ml-weather-prediction-case-study-Aaditya-Makwana/blob/main/WOC5_0_ML_Checkpoint_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io
# Out:
#      <input type="file" id="files-52ff87fe-6e39-4124-bbf6-305cad50768d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52ff87fe-6e39-4124-bbf6-305cad50768d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Q1
df = pd.read_csv("Youtube Influencer Analysis - Updated.csv", encoding = 'cp1252')
pd.set_option('max_columns', None)
df
# Out:
#                                             Video Link Video Views  \
# 0          https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1          https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2    https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3          https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4          https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
# ..                                                 ...         ...
# 900        https://www.youtube.com/watch?v=GS18WawA-t0       6,892
# 901        https://www.youtube.com/watch?v=_tc_APkjH2Q      16,554
# 902        https://www.youtube.com/watch?v=Xfj4osSYfhU      32,798
# 903        https://www.youtube.com/watch?v=mGEHqwVz0eI       1,503
# 904        https://www.youtube.com/watch?v=UGATpt0I4vA     429,966
#
#                                            Video Title  \
# 0      Samse - Didupe Off-road Royal Enfield Himalayan
# ...

# %%
#Q2
print("Dataframe with 'Creator Gender' as NaN :")
df[pd.isnull(df["Creator Gender"])]
print("NaN replaced with 'Rather not say' : ")
df["Creator Gender"].fillna("Rather not say")

# %%
#Q3
df.drop(['Video Title', 'Creator Gender', 'Language of the Video', 'Subtitle'], axis = 1)
# Out:
#                                             Video Link Video Views  \
# 0          https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1          https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2    https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3          https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4          https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
# ..                                                 ...         ...
# 900        https://www.youtube.com/watch?v=GS18WawA-t0       6,892
# 901        https://www.youtube.com/watch?v=_tc_APkjH2Q      16,554
# 902        https://www.youtube.com/watch?v=Xfj4osSYfhU      32,798
# 903        https://www.youtube.com/watch?v=mGEHqwVz0eI       1,503
# 904        https://www.youtube.com/watch?v=UGATpt0I4vA     429,966
#
#                                            Channel URL          Creator Name  \
# 0                  https://www.youtube.com/c/sriharick            srihari ck
# ...

# %%
#Q4
df["Creator Name"].str.encode(encoding = 'punycode')
# Out:
# 0                b'srihari ck-'
# 1               b'Chai Bisket-'
# 2               b'Virda Warsi-'
# 3                       b'TRT-'
# 4                     b'Vogue-'
#                  ...
# 900    b'Sahil Online TV News-'
# 901    b'Sahil Online TV News-'
# 902    b'Sahil Online Bhatkal-'
# 903    b'Sahil Online Bhatkal-'
# 904     b'Sony Sports Network-'
# Name: Creator Name, Length: 905, dtype: object
